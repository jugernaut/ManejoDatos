# %% [markdown]
# <a href="https://colab.research.google.com/github/jugernaut/ManejoDatos/blob/main/Bases_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bases de Datos**
#
# Profesor: M.en.C. Miguel Angel Pérez León.
#
# Ayudante: Jesús Iván Coss Calderón.
#
# Materia: Manejo de Datos

# %% [markdown]
# ## **Introducción**
#
# Una base de datos es cualquier colección de información a la cual se puede **acceder de manera organizada**, digamos por ejemplo, una colección bibliográfica, el archivo muerto de una empresa, un libro compuesto por hojas de calculo, etc.
#
# Las bases de datos se han ocupado desde los inicios de la civilización, sin embargo es hasta fechas recientes gracias al uso de las computadoras, que el organizar y acceder a la información contenida en una base de datos se ha vuelto una labor mucho mas rápida, sencilla y **persistente**.
#
# Cualquier usuario con conocimiento sobre **manejadores de bases de datos** puede acceder, modificar o eliminar información contenida en una base de datos, sin embargo las bases de datos cobran mayor importancia cuando se vinculan a algún algoritmo informático (aplicación, programa, etc) mediante el cual se puede obtener información de manera sistemática, como por ejemplo INEGI, Facebook, Google, YouTube, etc.

# %% [markdown]
# Ahora por otro lado, para poder decir que el acceso a la información de una base de datos se realiza de manera organizada, se debe garantizar que las consultas, actualización o eliminación de la información se llevan a cabo de manera eficiente.
#
#
#
# Una forma de llevar a cabo esta organización de manera eficiente es mediante **entidades** que agrupan un conjunto de elementos con los los mismos **atributos** y las **relaciones** que guardan los elementos de la base de datos.
#
#
#
# A esta forma de organizar la información se le conoce como el **modelo entidad-relacion** (modelo e-r). Una de las herramientas básicas del modelo e-r es el **diagrama entidad-relación**, también conocido como DER, en el cual se muestran de manera gráfica, las entidades, atributos y relaciones que existen dentro de la base de datos.

# %% [markdown]
# ## **Modelo E-R**

# %% [markdown]
# ### Características
#
# El modelo e-r es una herramienta para el modelado de datos que permite representar los elementos mas importantes de una colección de datos, así como sus atributos y relaciones. Los elementos que conforma el modelo e-r, son los siguientes:
#
#
#
# 1. **Entidades**: las entidades agrupan un conjunto de elementos que comparten el mismo numero y tipo de atributos en común, una entidad puede ser abstracta, como un préstamo o concreta, como una persona. Se representan mediante un rectángulo.
#
# 2. **Atributos**: son las elementos que caracterizan a las entidades (y a veces a las relaciones), por ejemplo si hablamos de la entidad 'alumnos' los atributos que comparten los alumnos son: nombre, edad, numero de cuenta. Se representan mediante un ovalo y en caso de ser un atributo llave (o identificador) se subraya dicho atributo.
#
# 3. **Relaciones**: como su nombre lo indica, establece la relación que guardan las entidades, por ejemplo la relación que tendría la entidad 'doctores' con 'pacientes' serian las 'consultas'. Las relaciones se representan mediante un rombo.

# %% [markdown]
# ### Cardinalidad de las relaciones
#
# Para modelar de manera mas apegada a la realidad las relaciones que se pueden dar en modelo e-r, se puede definir la cardinalidad que guardan las relaciones, es decir:
#
# * **(1,1)**: esto significa que un elemento de la entidad izquierda de la relación, solo puede estar relacionado con un elemento de la entidad derecha de la relación y viceversa. Ejemplo, un alumno solo puede estar relacionado a un historial académico y un historial académico solo puede estar relacionado con un alumno.
#
# * **(1,M)**: un elemento de la entidad izquierda de la relación puede estar relacionado con muchos elemento de la entidad derecha de la relación. Ejemplo, un cliente pueden tener varias facturas, varias facturas pueden estar a nombre del mismo cliente, pero no puede haber una factura a nombre de varios clientes.
#
# * **(M,N)**: varios elementos de la entidad izquierda de la relación pueden estar relacionados con varios elementos de la entidad derecha de la relación y viceversa. Ejemplo, diferentes clientes pueden comprar varios productos y varios productos pueden ser comprados por diferentes clientes.

# %% [markdown]
# ### Tipos de atributos
#
# Existen diferentes tipos de atributos que permiten describir de manera mas clara las características del modelo, estos son:
#
# * **Llave primaria**: es un único atributo que sirve para identificar de manera única a cada elemento de la entidad. Ejemplo, cada alumno es identificado de manera única mediante su 'numero de cuenta'.
#
# * **Super llave**: es un conjunto de atributos que, en conjunto identifica de manera única a cada elemento de la entidad. Ejemplo, en la entidad 'escritura', la super llave estaría formada por (año, libro, hoja, folio), en conjunto todos estos atributos identifican de manera única a una escritura.
#
# * **Llave foránea**: este atributo debe ser estrictamente la llave primaria de otra entidad para asegurar su existencia. Ejemplo, un alumno tiene como llave foranea la llave primaria de la entidad 'carreras' y mediante esta llave se puede identificar la carrera a la que pertenece cada alumno.

# %% [markdown]
# ### Diagrama extendido
#
# Como podrás notar, los elementos previamente descritos sirven para modelar la mayoría de las bases de datos, pero hay casos para los cuales son insuficientes, es por este motivo que existe el **modelo e-r extendido**.
#
# Sin embargo para el alcance de este curso, los elementos del modelo e-r son suficientes.
#
# ![der.PNG](data:image/png;base64,...)
#
# FIGURA: DER

# %% [markdown]
# ### DER
#
# ![broma.png](data:image/png;base64,...)
#
#
# FIGURA: ejemplo DER para el examen

# %% [markdown]
# ### Ejemplo
#
# Se pide modelar el siguiente sistema. Se requiere una base de datos donde:

# %% [markdown]
# 1. Se puedan almacenar alumnos, tutores y especialidades.
#
# 2. Cada alumno esta caracterizado por un numero de cuenta, un nombre y un tutor. Elige una llave primaria para cada alumno.
#
# 3. Cada alumno solo puede estar relacionado con un tutor, pero un tutor puede tener varios alumnos
#
# 4. Cada tutor esta caracterizado por su c.v., su nombre y la especialidad.
#
# 5. Cada tutor solo puede tener una especialidad, pero una especialidad puede pertenecer a diferentes tutores.
#
# 6. La relación entre alumnos y tutores debe tener como atributo el año en el que se dio la tutoría.
#
# 7. El sistema debe ser capaz de permitir que un tutor tenga diferentes alumnos, siempre y cuando sea en diferentes años. Y ademas el sistema debe ser capaz de almacenar un histórico de los alumnos que han sido tutorandos de algún tutor.

# %% [markdown]
# ## **Modelo Relacional**

# %% [markdown]
# ### Introducción
#
# El modelo relacional, es un concepto que introdujo la compañía I.B.M. en la década de los años 70 para la gestión y administración de las **bases de datos relacionales**.
#
#
# Este modelo esta basado en **lógica de predicados** y en **teoría de conjuntos**, por lo que muchas de las operaciones y propiedades de la lógica de predicados y de teoría de conjuntos, se aplican a este modelo.
#
# La idea básica de este modelo es enfatizar las relaciones que existen entre las diferentes entidades que componen el modelo. Dichas relaciones pueden pensarse en forma lógica como **conjuntos de datos llamados tuplas**.
#
# Actualmente la mayoría de las bases de datos se rigen mediante este modelo, aunque existen alternativas **no-relacionales** que han mostrado ser altamente eficientes.

# %% [markdown]
# A pesar de que la base del modelo relacional nos invita a conceptualizar los datos como un conjunto de información, a la cual se le pueden aplicar operadores lógicos y de conjuntos, normalmente es mas sencillo pensar que todo elemento del modelo relacional es una tabla, en la cual **cada columna es un campo o atributo** y **cada renglón un registro**.

# %% [markdown]
# ### Ejemplo 1:
#
# ![modelor.jpg](data:image/jpeg;base64,...)
#
# FIGURA: modelo relacional

# %% [markdown]
# ### Ejemplo 2:
#
# ![modelor2.png](data:image/png;base64,...)
#
# FIGURA: Modelo relacional

# %% [markdown]
# ### Reglas del modelo relacional
#
# El modelo relacional establece que se debe definir de manera clara el **nombre** y **tipo** de cada uno de los atributos de la entidad o relación y por otro lado, especifica que las 2 reglas principales que rigen el modelo relacional son las siguientes:
#
# 1. **Integridad de Entidades**: ninguna llave primaria puede contener un valor nulo.
#
# 2. **Integridad referencial**:
#
#   * Una tupla que referencia a otra (de la misma u otra relación), debe referirse a una tupla existente en dicha relación.
#
#   * Se puede hacer referencia a otra tupla mediante una llave foránea y por la regla previa, dicha llave foránea no puede contener un valor nulo.

# %% [markdown]
# ### Normalización (o forma normal) de una base de datos
#
# Para normalizar una base de datos, se deben de aplicar una serie de reglas a las relaciones obtenidas después de haber pasado del modelo e-r al modelo relacional. Esto con la intención de:
# * **Evitar redundancia de los datos**: Esto significa que la información no se repetirá en diferentes relaciones de la base de datos y por lo tanto se utiliza menos memoria para almacenar la información. Depende en gran medida del fin que se le vaya a dar a la base de datos, si es conveniente tener redundancia en los datos.
#
# * **Disminuir problemas de actualización**: Si la información dentro de la base de datos se encuentra repetida en diferentes tablas, cuando se lleva a cabo una actualización es necesario actualizar todas las tablas donde se encuentre el dato que fue modificado.
#
# * **Integridad de los datos**: Se refiere a que los datos sean correctos y completos, es decir que no hayan sido corrompidos después de alguna operación.

# %% [markdown]
# ## **Algebra Relacional**
#
# El álgebra relacional se puede definir como un conjunto de operaciones que ayudan a describir paso a paso como es que se pueden realizar consultas sobre la información que haya sido almacenada empleando el modelo relacional. Es denominada **procedimental**, a diferencia del **calculo relacional** que es de tipo declarativo.
#
# Es muy importante recalcar que todas las operaciones del álgebra relacional se aplican a relaciones (tablas) del modelo relacional y que el resultado de estas operaciones, es a su vez una tabla, aunque el resultado de dicha operación sea la tabla vacía.
#
# De tal manera que es posible anidar tantas operaciones (**consultas**) como sean necesarias para obtener, eliminar o actualizar la información que necesitemos.

# %% [markdown]
# ### Conceptos Básicos
#
# Dado que para poder pasar del modelo relacional al uso de álgebra relacional se tiene que ser mas pragmático, es necesario tener en cuenta los siguientes conceptos:
#
# * **Base de datos (B.D.)**: colección de relaciones.
#
# * **Relación**: conjunto de tuplas (igual que en teoría de conjuntos, no tiene sentido una tupla repetida).
#
# * **Esquema de la relación**: sean $A_{1},...,A_{n}$ atributos de una relación, podemos pensar en que dicha relación se ve así $R(A_{1},...A_{n})$.
#
# * **Estado de la relación**: sea $r=(t_{1},t_{2},...,t_{n})$ un conjunto de tuplas de la relación $r$, donde cada valor $v_{i}$ de $t_{i}$ con $1\leq i\leq n$ es:
#
#   * un elemento de $dom(A_{i})$.
#
#   * o un valor nulo.
#
# * **Orden entre las tuplas**: no se considera, a menos que se especifique lo contrario.

# %% [markdown]
# ### Restricciones de Integridad
#
# De igual manera que con el modelo relacional, el álgebra relacional establece un conjunto de restricciones, con la intención de mantener la integridad referencial.
#
# * **De dominio**: valor atómico de un tipo, es decir que un atributo no puede estar compuesto por mas de un tipo de dato.
#
# * **De clave**: atributos que identifican de manera única a cada tupla.
#
# * **Integridad de entidades**: ninguna clave primaria puede contener el valor nulo.
#
# * **Integridad referencial**:
#
#   * Una tupla que referencia a otra (de la misma u otra relación) debe referirse a una tupla existente.
#
#   * Si se hace referencia a otra tupla mediante una clave foránea, se pide que esta no sea nula.

# %% [markdown]
# #### Ejemplo de relación:
#
# ![relacion.png](data:image/png;base64,...)
#
# FIGURA: Relación

# %% [markdown]
# #### Ejemplo de llave foránea:
#
#
# ![foranea.png](data:image/png;base64,...)
#
#
# FIGURA: Llave foránea

# %% [markdown]
# ### Operaciones ABC (altas, bajas, cambios)
#
#
# * Cuando se aplica alguna de estas 3 operaciones es importante respetar las restricciones de integridad y validar que no se haya violado alguna de las restricciones de integridad.
#
#   * Insertar.
#
#   * Eliminar.
#
#   * Actualizar.
#
# * Insertar y eliminar pueden violar las 4 restricciones.
#
# * Actualizar solo puede violar la restricción referencial.
#
# * La mayoría de los manejadores de bases de datos, permiten asociar eventos a violaciones de integridad. De tal manera que en caso de que se viole alguna de estas restricciones, el manejador se encarga de **mantener los datos persistentes**.

# %% [markdown]
# ### Operaciones del álgebra relacional
#
# Las operaciones del álgebra relacional las podemos agrupar por el tipo de operación y su aridad, es decir:
#
# * Operadores específicos del álgebra relacional:
#
#   * Seleccionar y Proyectar: son de aridad unaria.
#
#   * Reunión (Join): de aridad binaria.
#
# * Operadores de teoría de conjuntos:
#
#   * Unión, Intersección, Diferencia y Producto Cartesiano: mismo tipo de aridad que en teoría de conjuntos.
#
# * Otros operadores:
#
#   * División.
#
#   * Funciones agregadas y de agrupación: group by, order by, $avg$, $min$, $max$.

# %% [markdown]
# ### Selección $\sigma$
#
# Selecciona un subconjunto de tuplas de la relación, que cumplan con determinados criterios.
#
# * Condiciones: $\{=,\leq,<,>,\geq,\neq,\land,\lor\}$
#
# * Es Conmutativa: $$\sigma_{cond1}(\sigma_{cond2}(R))=\sigma_{cond2}(\sigma_{cond1}(R)) \quad \text{y} \quad \sigma_{cond1}(\sigma_{cond2}(R))=\sigma_{cond1\,\land cond2}(R)$$
#
# ![empleado.png](data:image/png;base64,...)
#
# FIGURA: Relación Empleado

# %% [markdown]
# ![sigma.png](data:image/png;base64,...)
#
# FIGURA: $\sigma_{ND=4}(Empleado)$

# %% [markdown]
# ### Proyección $\pi$
#
# Selecciona un subconjunto de **atributos** de la relación.
#
# * Elimina tuplas repetidas.
#
# * No es conmutativa: $\pi_{lista1}(\pi_{lista2}(R))=\pi_{lista1}(R)$
#
# ![emp2.png](data:image/png;base64,...)
#
# FIGURA: Relación Empleado

# %% [markdown]
# ![proye.png](data:image/png;base64,...)
#
# FIGURA: $\pi_{SEXO,SALARIO}(Empleado)$

# %% [markdown]
# ### Renombrar y Resultados intermedios
#
# Hay veces que para lograr una consulta en especifico se recomienda realizar consultas intermedias (anidadas) o renombrar los resultados obtenidos.
#
# ![emp3.png](data:image/png;base64,...)
#
# FIGURA: Relación Empleado

# %% [markdown]
# ![interme.png](data:image/png;base64,...)
#
# FIGURA: Resultado Intermedio

# %% [markdown]
# ![renombre.png](data:image/png;base64,...)
#
# FIGURA: Renombre de atributos

# %% [markdown]
# Alternativa sin renombre o resultados intermedios
# $$\pi_{NOMBRE,APELLIDO,SALARIO}(\sigma_{ND=5}(EMPLEADO))$$

# %% [markdown]
# ### Unión, Intersección y Diferencia
#
# * Para poder llevar a cabo la unión, es necesario que ambas **relaciones sean compatibles**, es decir que ambas relaciones tengan el mismo tipo de atributos en el mismo orden.
#
# * Conservan las misma propiedades que sus equivalentes de teoría de conjuntos.
#
# ![alumprof.png](data:image/png;base64,...)
#
# FIGURA: ALUMNO, PROFESOR

# %% [markdown]
# ![union.png](data:image/png;base64,...)
#
# FIGURA: Unión

# %% [markdown]
# ![inter.png](data:image/png;base64,...)
#
# FIGURA: Intersección

# %% [markdown]
# ![dif.png](data:image/png;base64,...)
#
# FIGURA: Diferencia

# %% [markdown]
# ### Producto Cartesiano
#
# * Para que el producto cartesiano tenga sentido, se pide que las relaciones involucradas en esta operaciones, **no sean compatibles con la unión**.
#
# * Sean $R(A_{1},\ldots,A_{n}) y S(B_{1},\ldots,B_{m})$, entonces $R\times S=Q(A_{1},\ldots A_{n},B_{1},\ldots B_{m})$, donde:
#
#   * $Q$ tiene $n*m$ tuplas.
#
#   * $Q$ consta de todas las combinaciones de cada tupla de $R$ seguida de otra de $S$.
#
# ![prodcar.png](data:image/png;base64,...)
#
# FIGURA: PR_STAF, DP_STAF

# %% [markdown]
# ![resultadoprodcar.png](data:image/png;base64,...)
#
# FIGURA: Producto Cartesiano

# %% [markdown]
# ### Join (Reunión)
#
# * **Combina tuplas que comparten al menos un tipo de atributo en común y cuyo valor es el mismo en ambas relaciones**, es decir tuplas que están relacionadas entre si.
#
# * Es una de las operaciones mas importantes para las bases de datos relacionales.
#
# * Permite preservar vínculos entre relaciones.
#
# ![emp.png](data:image/png;base64,...)
#
# FIGURA: Relación Empleado

# %% [markdown]
# ![depto.png](data:image/png;base64,...)
#
# FIGURA: Relación Departamento

# %% [markdown]
# ![jefedepto.png](data:image/png;base64,...)
#
# FIGURA: JEFE_DEPTO $\leftarrow$DPT $\bowtie_{NSS_{-}JEFE=NSS}EMP$

# %% [markdown]
# * Sean $R(A_{1},\ldots,A_{n})$ y $S(B_{1},\ldots,B_{m})$ relaciones no compatibles con la unión.
#
# * Sea $R(A_{1},\ldots,A_{n})\bowtie_{COND}S(B_{1},\ldots,B_{m})=Q(A_{1},\ldots A_{n},B_{1},\ldots B_{m})$, donde:
#
#   * Q consta de todas las combinaciones de cada tupla de R seguida de otra tupla de S, que satisfaga la condición de Join COND.
#
#   * Si ninguna combinación cumple la condición COND el resultado es la **relación vacía**.
#
# * Condición COND:
#
#   * Se evalúa para cada combinación de tuplas.
#
#   * Tiene la forma: $<subcondici\acute{o}n>\wedge<subcondici\acute{o}n>\wedge\ldots\wedge<subcondici\acute{o}n>$
#
#   * Cada subcondición tiene la forma: $A_{i}\,\theta\,B_{j}$ donde $A_{i}\in R\,$ y $\,B_{j}\in S\,$ y $\,\theta\in\{=,<,\leq,\geq,>,\neq\}$.

# %% [markdown]
# ### Natural Join
#
# * *COND* implícita: igualdad de todos los atributos con el mismo nombre.
#
# * El resultado siempre tiene pares de atributos con valores idénticos en todas las tuplas.
#
# * Se eliminan atributos repetidos en la relación.
#
# * Debe existir al menos un par de atributos con el mismo nombre y tipo en ambas relaciones.
#
# ![natural.png](data:image/png;base64,...)
#
# FIGURA: Natural Join

# %% [markdown]
# ![resjoin.png](data:image/png;base64,...)
#
# FIGURA: DEPTO_PROY $\leftarrow PRY * DPT$

# %% [markdown]
# ### División
#
# Sean $N$ y $D$ dos relaciones con el siguiente esquema.
#
# ![div.png](data:image/png;base64,...)
#
# FIGURA: División

# %% [markdown]
# * Por cada atributo de $D$ debe existir otro en $N$ de igual nombre, $Y\subseteq X$.
#
# * El resultado tiene los atributos de $N$ que no pertenecen a $D$.
#
# * Son tuplas del resultado $t\in R$, las que cumplen:
#
#   * La combinación de valores de $t$ está en alguna tupla de $N$.
#
#   * Esa combinación de valores de $t$ se encuentra en tuplas de $N$ junto todas y cada una de las combinaciones de valores de las tuplas de $D$.
#
# * Es decir que $t\in R$ si y solo si:
#
# * $\forall t_{D}\in D\,\exists t_{N}\in N\,tal\,que\,(t=t_{N}[Z]\,\wedge\,t_{D}=t_{N}[Y])$.

# %% [markdown]
# #### Ejemplo 5:
#
# Obtener el $NSS$ de los empleados que trabajan en **todos y cada uno** de los proyectos en los que trabaja el trabajador con $NSS=123456789$.

# %% [markdown]
# * Esta consulta conviene pensarla en partes para que sea mas sencillo:
#
#   * Primero: proyectamos nombre y $NSS$ de todos los proyectos en los que participan todos y cada uno de los empelados y guardamos el resultado intermedio como $NSS_{-}N\acute{U}M_{-}PRY$.
#
#   * Segundo: proyectamos los proyectos en los cuales participa el empleado con $NSS=123456789$, guardamos resultado como $N\acute{U}MS_{-}PRY$.
#
#   * Ultimo: realizamos la división $NSS_{-}N\acute{U}M_{-}PRY \div N\acute{U}MS_{-}PRY$.

# %% [markdown]
# ![ejemodiv.png](data:image/png;base64,...)
#
# FIGURA: División

# %% [markdown]
# ## **Manejadores de Bases de Datos**

# %% [markdown]
# ### Introducción
#
# Dado lo ya mencionado en secciones pasadas, la importancia de las bases de datos debe ser clara para este momento.
#
#
#
# Un manejador de bases de datos es un programa (algoritmo) que nos permite acceder a los datos de manera eficiente, organizada y sobretodo que no viola las restricciones mencionadas para el modelo relacional.
#
#
#
# Para lograr esta eficiencia, un manejador de datos emplea algoritmos de búsqueda, **algoritmos de ordenamientos, arboles de decisión, expresiones regulares, tablas de dispersión**, entre otros.
#
#
#
# En la actualidad existen muchos manejadores de bases de datos (incluso algunos no-relacionales). Existen desde los mas básicos, hasta los mas completos, la elección del manejador de base de datos depende del contexto para el que se vaya a usar, es decir: recursos, seguridad, desempeño, presupuesto.

# %% [markdown]
# ### SQL
#
# Del ingles Structured Query Language (SQL), es el lenguaje que nos permite interactuar con el manejador de bases de datos para acceder a los datos almacenados. Sus principales características son:
#
# * Primer lenguaje en incorporar el modelo relacional para llevar a cabo consultas a los datos almacenados.
#
# * Es un lenguaje libre y de dominio especifico, lo que significa que no es necesario pagar una licencia para poder hacer uso de este.
#
# * Esta diseñado para incorporar los conceptos de calculo y álgebra relacional para llevar a cabo las consultas a la base de datos.
#
# * SQL pasó a ser el estándar del Instituto Nacional Estadounidense de Estándares (ANSI) en 1986 y de la Organización Internacional de Normalización (ISO) en 1987.

# %% [markdown]
# ### MySQL
#
# MySQL es el manejador de bases de datos que se utilizará a lo largo del curso, se caracteriza por:
#
# * Es un manejador de bases de datos relacional.
#
# * Manejador de código abierto, es decir que cualquiera puede descargar el código fuente.
#
# * A la par de Oracle, Microsoft SQL Server, MySQL es de los manejadores mas populares para el desarrollo web.

# %% [markdown]
# ### Comandos
#
# Los principales comandos que se utilizan en MySQL se muestran a continuación:
#
# * Create: permite crear usuarios, bases de datos, tablas, restricciones, etc.
#
# * Insert: mediante este comando se insertan valores dentro de una base de datos.
#
# * Update: comando que nos permite actualizar la información dentro de la base de datos.
#
# * Drop: este comando es usado para eliminar desde tabla, hasta una base de datos completa.
#
# * Select: permite seleccionar un conjunto de datos (es el equivalente a la proyección).
#
# * Where: mas que un comando es una clausula, que en combinación con Select, permite seleccionar solo los datos que cumplan con un determinado criterio.

# %% [markdown]
# ## **Apendice**

# %% [markdown]
# ### Referencias
#
# * Greg Riccardi: Principles of Database Systems with Internet an Java Aplications.
#
# * Referencias  Anexo: Algebra relacional, https://www.unirioja.es/cu/arjaime/Temas/04.Anexo.pdf
#
# * Referencias  https://www.w3schools.com/sql/
#
# * Referencias  http://mysql.conclase.net/curso/?cap=000#
#
# * Referencias  http://didepa.uaemex.mx/clases/Manuales/MySql/MySql-La%20biblia%20de%20mysql.pdf
#
# * Referencias  https://downloads.mysql.com/docs/refman-5.0-es.pdf
